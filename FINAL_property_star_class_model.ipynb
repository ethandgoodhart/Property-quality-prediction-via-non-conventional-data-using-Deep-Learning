# %% [markdown]
# # **(optional) Preprocessing download dataset images and clean table rows**

# %%
## IMPORTANT: The following files/folders must be present in the current directory before running pre-processing
#
# 1. final_data.csv
# 2. cs230_numerical.csv
# 3. /listings folder containing .json files

# %%
# Install grequests for fast-async requests to download images
# !pip install grequests
import grequests

# %%
# Patch to fix bug and remove extra logging each time grequests is uses
import sys
del sys.modules["grequests"]
del grequests
del sys.modules["gevent.monkey"]

# %%
# Now, reinstall grequests
# !pip install grequests
import grequests
# Out:
# Requirement already satisfied: grequests in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: gevent in /usr/local/lib/python3.10/dist-packages (from grequests) (24.11.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from grequests) (2.32.3)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.10/dist-packages (from gevent->grequests) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.10/dist-packages (from gevent->grequests) (7.2)
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from gevent->grequests) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->grequests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->grequests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->grequests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->grequests) (2024.8.30)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.event->gevent->grequests) (75.1.0)

# %%
# %env GEVENT_SUPPORT=True
# Out:
# env: GEVENT_SUPPORT=True

# %%
final_df = pd.read_csv('final_data.csv') # 2986 rows
cs230_df = pd.read_csv('cs230_numerical.csv').drop('Unnamed: 0', axis=1) # 647 rows

# %%
# Original CS230 df specs
print(cs230_df.columns, len(cs230_df.columns))
# Out:
# Index(['name', 'city', 'Width', 'Height', 'Brightness', 'Color', 'Dominate',
#        'description', 'stars', 'price', 'rating', 'reviews', 'image', 'images',
#        'categoryReviews', 'userReviews', 'staff', 'facilities', 'cleanliness',
#        'comfort', 'valueForMoney', 'location', 'albuquerque', 'austin',
#        'baltimore', 'bonston', 'calgary', 'charlotte', 'chicago', 'columbus',
#        'dallas', 'denver', 'detroit', 'el_paso', 'fort_worth', 'fresno',
#        'houston', 'indianapolis', 'jacksonville', 'kansas', 'las_vegas',
#        'los_angeles', 'louiseville', 'memphis', 'mesa', 'milwaukee',
#        'montreal', 'nashville', 'new_york', 'oklahoma_city', 'orlando',
#        'philadelphia', 'phoenix', 'portland', 'sacramento', 'san_antonio',
#        'san_diego', 'san_francisco', 'san_jose', 'seattle', 'toronto',
#        'tucson', 'washington_dc', 'c1', 'c2', 'c3', 'd1', 'd2', 'd3',
#        'travelweekly_year_built', 'travelweekly_num_floors',
#        'travelweekly_num_rooms', 'travelweekly_chain',
#        'travelweekly_events_num_rooms', 'travelweekly_events_total_sqft',
#        'travelweekly_min_rate', 'travelweekly_max_rate', 'num_room_types',
#        'standard_room_sqft'],
#       dtype='object') 79

# %%
img_updated_rows = []
for index, row in cs230_df.iterrows():
  clean_images_np = []
  img_list = row['images'][2:-2].split("', '")

  rs = (grequests.get(iurl, timeout=2.5) for iurl in img_list)
  mapped = grequests.map(rs)

  for res in mapped:
    if res.status_code == 200:
      clean_images_np.append(np.array(Image.open(BytesIO(res.content))))

  print('Fetched', len(clean_images_np), 'images for row', index)
  img_updated_rows.append(row.to_list() + [clean_images_np[:10]])
# Out:
# Fetched 9 images for row 0
# Fetched 52 images for row 1
# Fetched 50 images for row 2
# Fetched 45 images for row 3
# Fetched 36 images for row 4
# Fetched 37 images for row 5
# Fetched 27 images for row 6
# Fetched 52 images for row 7
# Fetched 53 images for row 8
# Fetched 18 images for row 9
# Fetched 38 images for row 10
# Fetched 3 images for row 11
# Fetched 2 images for row 12
# Fetched 48 images for row 13
# Fetched 26 images for row 14
# Fetched 20 images for row 15
# Fetched 52 images for row 16
# Fetched 10 images for row 17
# Fetched 10 images for row 18
# Fetched 45 images for row 19
# Fetched 6 images for row 20
# Fetched 22 images for row 21
# Fetched 37 images for row 22
# Fetched 24 images for row 23
# Fetched 43 images for row 24
# Fetched 46 images for row 25
# Fetched 44 images for row 26
# Fetched 24 images for row 27
# Fetched 12 images for row 28
# Fetched 43 images for row 29
# Fetched 47 images for row 30
# Fetched 2 images for row 31
# Fetched 3 images for row 32
# Fetched 2 images for row 33
# Fetched 15 images for row 34
# Fetched 47 images for row 35
# Fetched 49 images for row 36
# Fetched 7 images for row 37
# Fetched 3 images for row 38
# Fetched 0 images for row 39
# Fetched 34 images for row 40
# Fetched 0 images for row 41
# Fetched 34 images for row 42
# Fetched 32 images for row 43
# Fetched 4 images for row 44
# Fetched 5 images for row 45
# Fetched 6 images for row 46
# Fetched 3 images for row 47
# Fetched 14 images for row 48
# Fetched 33 images for row 49
# Fetched 5 images for row 50
# Fetched 26 images for row 51
# Fetched 8 images for row 52
# Fetched 0 images for row 53
# Fetched 0 images for row 54
# Fetched 2 images for row 55
# Fetched 2 images for row 56
# Fetched 0 images for row 57
# Fetched 1 images for row 58
# Fetched 36 images for row 59
# Fetched 0 images for row 60
# Fetched 0 images for row 61
# Fetched 0 images for row 62
# Fetched 0 images for row 63
# Fetched 0 images for row 64
# Fetched 40 images for row 65
# Fetched 36 images for row 66
# Fetched 0 images for row 67
# Fetched 0 images for row 68
# Fetched 0 images for row 69
# Fetched 0 images for row 70
# Fetched 0 images for row 71
# Fetched 3 images for row 72
# Fetched 47 images for row 73
# Fetched 2 images for row 74
# Fetched 2 images for row 75
# Fetched 47 images for row 76
# Fetched 23 images for row 77
# Fetched 31 images for row 78
# Fetched 41 images for row 79
# Fetched 0 images for row 80
# Fetched 1 images for row 81
# Fetched 7 images for row 82
# Fetched 45 images for row 83
# Fetched 41 images for row 84
# Fetched 0 images for row 85
# Fetched 0 images for row 86
# Fetched 28 images for row 87
# Fetched 17 images for row 88
# Fetched 40 images for row 89
# Fetched 45 images for row 90
# Fetched 53 images for row 91
# Fetched 2 images for row 92
# Fetched 45 images for row 93
# Fetched 46 images for row 94
# Fetched 2 images for row 95
# Fetched 34 images for row 96
# Fetched 48 images for row 97
# Fetched 36 images for row 98
# Fetched 47 images for row 99
# Fetched 33 images for row 100
# Fetched 0 images for row 101
# Fetched 0 images for row 102
# Fetched 0 images for row 103
# Fetched 46 images for row 104
# Fetched 18 images for row 105
# Fetched 1 images for row 106
# Fetched 39 images for row 107
# Fetched 54 images for row 108
# Fetched 50 images for row 109
# Fetched 13 images for row 110
# Fetched 44 images for row 111
# Fetched 35 images for row 112
# Fetched 47 images for row 544
# Fetched 46 images for row 545
# Fetched 5 images for row 546
# Fetched 1 images for row 547
# Fetched 39 images for row 548
# Fetched 53 images for row 549
# Fetched 7 images for row 550
# Fetched 6 images for row 551
# Fetched 7 images for row 552
# Fetched 29 images for row 553
# Fetched 48 images for row 554
# Fetched 14 images for row 555
# Fetched 48 images for row 556
# Fetched 12 images for row 557
# Fetched 4 images for row 558
# Fetched 47 images for row 559
# Fetched 1 images for row 560
# Fetched 46 images for row 561
# Fetched 20 images for row 562
# Fetched 1 images for row 563
# Fetched 0 images for row 564
# Fetched 46 images for row 565
# Fetched 1 images for row 566
# Fetched 4 images for row 567
# Fetched 41 images for row 568
# Fetched 41 images for row 569
# Fetched 4 images for row 570
# Fetched 0 images for row 571
# Fetched 45 images for row 572
# Fetched 46 images for row 573
# Fetched 1 images for row 574
# Fetched 0 images for row 575
# Fetched 46 images for row 576
# Fetched 1 images for row 577
# Fetched 47 images for row 578
# Fetched 0 images for row 579
# Fetched 2 images for row 580
# Fetched 25 images for row 581
# Fetched 0 images for row 582
# Fetched 15 images for row 583
# Fetched 43 images for row 584
# Fetched 45 images for row 585
# Fetched 2 images for row 586
# Fetched 39 images for row 587
# Fetched 41 images for row 588
# Fetched 48 images for row 589
# Fetched 2 images for row 590
# Fetched 49 images for row 591
# Fetched 1 images for row 592
# Fetched 18 images for row 593
# Fetched 44 images for row 594
# Fetched 22 images for row 595
# Fetched 50 images for row 596
# Fetched 1 images for row 597
# Fetched 48 images for row 598
# Fetched 3 images for row 599
# Fetched 50 images for row 600
# Fetched 0 images for row 601
# Fetched 0 images for row 602
# Fetched 0 images for row 603
# Fetched 46 images for row 604
# Fetched 0 images for row 605
# Fetched 46 images for row 606
# Fetched 40 images for row 607
# Fetched 0 images for row 608
# Fetched 28 images for row 609
# Fetched 0 images for row 610
# Fetched 7 images for row 611
# Fetched 13 images for row 612
# Fetched 23 images for row 613
# Fetched 46 images for row 614
# Fetched 29 images for row 615
# Fetched 36 images for row 616
# Fetched 0 images for row 617
# Fetched 38 images for row 618
# Fetched 34 images for row 619
# Fetched 2 images for row 620
# Fetched 38 images for row 621
# Fetched 27 images for row 622
# Fetched 7 images for row 623
# Fetched 7 images for row 624
# Fetched 47 images for row 625
# Fetched 52 images for row 626
# Fetched 47 images for row 627
# Fetched 6 images for row 628
# Fetched 24 images for row 629
# Fetched 13 images for row 630
# Fetched 18 images for row 631
# Fetched 20 images for row 632
# Fetched 0 images for row 633
# Fetched 0 images for row 634
# Fetched 22 images for row 635
# Fetched 47 images for row 636
# Fetched 8 images for row 637
# Fetched 3 images for row 638
# Fetched 3 images for row 639
# Fetched 7 images for row 640
# Fetched 35 images for row 641
# Fetched 4 images for row 642
# Fetched 31 images for row 643
# Fetched 29 images for row 644
# Fetched 8 images for row 645
# Fetched 54 images for row 646

# %%
images_df = pd.DataFrame(img_updated_rows, columns=['name', 'city', 'Width', 'Height', 'Brightness', 'Color', 'Dominate',
       'description', 'stars', 'price', 'rating', 'reviews', 'image', 'images',
       'categoryReviews', 'userReviews', 'staff', 'facilities', 'cleanliness',
       'comfort', 'valueForMoney', 'location', 'albuquerque', 'austin',
       'baltimore', 'bonston', 'calgary', 'charlotte', 'chicago', 'columbus',
       'dallas', 'denver', 'detroit', 'el_paso', 'fort_worth', 'fresno',
       'houston', 'indianapolis', 'jacksonville', 'kansas', 'las_vegas',
       'los_angeles', 'louiseville', 'memphis', 'mesa', 'milwaukee',
       'montreal', 'nashville', 'new_york', 'oklahoma_city', 'orlando',
       'philadelphia', 'phoenix', 'portland', 'sacramento', 'san_antonio',
       'san_diego', 'san_francisco', 'san_jose', 'seattle', 'toronto',
       'tucson', 'washington_dc', 'c1', 'c2', 'c3', 'd1', 'd2', 'd3',
       'travelweekly_year_built', 'travelweekly_num_floors',
       'travelweekly_num_rooms', 'travelweekly_chain',
       'travelweekly_events_num_rooms', 'travelweekly_events_total_sqft',
       'travelweekly_min_rate', 'travelweekly_max_rate', 'num_room_types',
       'standard_room_sqft', 'np_images_ten'])
filtered_imgs_df = images_df[images_df['np_images_ten'].map(len) > 0]

# imgs_df.to_csv('cs230_w_images.csv')
print(filtered_imgs_df)
filtered_imgs_df.to_pickle('cs230_w_images.pickle.gzde', compression='gzip')
# Out:
#                                                   name           city  Width  \
# 0                        Sheraton Centre Toronto Hotel        toronto   1024
# 1                 Executive Hotel Cosmopolitan Toronto        toronto   1024
# 2                                  Bisha Hotel Toronto        toronto   1024
# 3    Holiday Inn Toronto Downtown Centre, an IHG Hotel        toronto   1024
# 4                     Delta Hotels by Marriott Toronto        toronto   1024
# ..                                                 ...            ...    ...
# 642  Holiday Inn Louisville Airport South, an IHG H...    louiseville   1024
# 643  Holiday Inn Express Louisville Airport Expo Ce...    louiseville   1024
# 644  Candlewood Suites Louisville Airport, an IHG H...    louiseville   1024
# 645  Crowne Plaza Louisville Airport Expo Center, a...    louiseville   1024
# 646   Kimpton Hotel Monaco Washington DC, an IHG Hotel  washington_dc   1008
#
#      Height  Brightness                                     Color  \
# 0       683  155.256676  [160.03191629 154.12408206 149.43024942]
# 1       683   83.055545     [92.64822875 80.32992228 73.82429167]
# 2       698  124.711664  [125.08205643 124.53883865 125.15122028]
# 3       683  151.273481  [157.78680911 150.75462116 131.68814914]
# 4       683  130.871141  [142.68008356 127.70386421 118.32489791]
# ..      ...         ...                                       ...
# 642     768  141.268715     [141.2687149 141.2687149 141.2687149]
# 643     576  116.604298  [123.89938694 115.25681559 102.72900899]
# 644     688  111.581214  [115.10372428 110.48679511 109.95480276]
# 645     683  144.993956  [153.52769691 143.26341594 130.62806266]
# 646     768  112.686788  [134.41314407 107.41188074  73.95429145]
#
#                                Dominate  \
# 0       [200.57826 200.7613  203.15504]
# 1       [19.295359 15.373721 14.762594]
# 2       [170.05089 169.21521 166.77252]
# 3       [183.58603 179.1546  161.714  ]
# 4    [110.95356   77.24888   60.295742]
# ..                                  ...
# 642     [168.02182 168.02182 168.02182]
# 643     [139.84195 140.03319 134.51721]
# 644     [166.22665 166.22154 167.62695]
# 645     [187.40617 179.84872 166.5323 ]
# 646  [151.13795  131.25827  111.890564]
#
#                                            description     stars     price  \
# 0    Located in the center of downtown Toronto, thi...  0.991736  6.146329
# 1    Executive Hotel Cosmopolitan Toronto is locate...  0.991736  5.786897
# 2    Located in the heart of downtown Toronto's Ent...  2.234641  6.202536
# 3    This hotel is located next door to Maple Leaf ...  0.991736  5.652489
# 4    Located in the heart of downtown Toronto, the ...  0.991736  6.194405
# ..                                                 ...       ...       ...
# 642  This Kentucky hotel offers free 24-hour airpor... -0.251169  4.976734
# 643  This Louisville hotel is 4.3 mi from the Kentu... -0.251169  4.828314
# 644  This Louisville, Kentucky hotel is located 3 m... -1.494074  4.672829
# 645  Only a short distance from Churchill Downs, th...  0.991736  5.023881
# 646  Located 2,450 feet from Walter E. Washington C...  2.234641  5.988961
#
#      ...  travelweekly_num_floors  travelweekly_num_rooms  \
# 0    ...                     43.0                    1372
# 1    ...                     26.0                      50
# 2    ...                     44.0                      96
# 3    ...                     23.0                     513
# 4    ...                     46.0                     567
# ..   ...                      ...                     ...
# 642  ...                      6.0                     122
# 643  ...                      4.0                     150
# 644  ...                      3.0                     100
# 645  ...                      5.0                     588
# 646  ...                      3.0                     184
#
#                 travelweekly_chain travelweekly_events_num_rooms  \
# 0                         Sheraton                          60.0
# 1       Executive Hotels & Resorts                           1.0
# 2                     Loews Hotels                           1.0
# 3               Holiday Inn Hotels                           9.0
# 4         Delta Hotels by Marriott                          11.0
# ..                             ...                           ...
# 642             Holiday Inn Hotels                           3.0
# 643     Holiday Inn Express Hotels                           3.0
# 644              Candlewood Suites                           1.0
# 645  Crowne Plaza Hotels & Resorts                          24.0
# 646   Kimpton Hotels & Restaurants                          10.0
#
#     travelweekly_events_total_sqft travelweekly_min_rate  \
# 0                         130000.0                   203
# 1                            954.0                   263
# 2                           2000.0                   368
# 3                           9000.0                   101
# 4                           9298.0                   305
# ..                             ...                   ...
# 642                         1650.0                    83
# 643                         2827.0                    69
# 644                            NaN                   109
# 645                        50000.0                    95
# 646                        16777.0                   383
#
#      travelweekly_max_rate  num_room_types  standard_room_sqft  \
# 0                      285              21               300.0
# 1                      308               9               360.0
# 2                     1099              23               400.0
# 3                      165              36               220.0
# 4                      454              25               360.0
# ..                     ...             ...                 ...
# 642                     83              21               500.0
# 643                    475              14                 NaN
# 644                    109              14               323.0
# 645                     95              50               300.0
# 646                    852              33               325.0
#
#                                          np_images_ten
# 0    [[[[39 37 35], [39 37 35], [39 37 35], [39 37 ...
# 1    [[[[206 209 216], [206 209 216], [206 209 216]...
# 2    [[[[156 156 154], [162 162 160], [167 167 165]...
# 3    [[[[23  3  4], [24  4  5], [24  4  5], [25  5 ...
# 4    [[[[16  2  2], [15  3  3], [16  4  6], [12  3 ...
# ..                                                 ...
# 642  [[[[247 243 242], [252 248 247], [255 251 248]...
# 643  [[[[117 130 139], [119 132 141], [121 134 143]...
# 644  [[[[200 200 198], [174 174 172], [176 176 174]...
# 645  [[[[10 19  0], [15 24  3], [17 27  3], [18 28 ...
# 646  [[[[178 160 148], [178 160 148], [179 161 149]...
#
# [541 rows x 80 columns]

# %%
# !gdown https://drive.google.com/uc?id=1uxjNcf52IyvCoURJ0nH0riUJ_8NYI8-h

# %%
imgs_df = pd.read_pickle('cs230_w_images.pickle.gzde', compression='gzip') # imgs_df = filtered_imgs_df
imgs_df = imgs_df[imgs_df['np_images_ten'].map(len) >= 4]

# %%
# Need to fix ['stars', 'rating', 'reviews', 'staff', 'facilities', 'cleanliness', 'comfort', 'valueForMoney', 'location']
last_city = ''
hotels_data = []
denorm_df_rows = []

for row_index, row in imgs_df.iterrows():
  fixed_row = []

  if row['city'] != last_city:
    last_city = row['city']
    with open(f"listings/{row['city']}_hotels.json", 'r') as file:
      hotels_data = json.load(file)

  for hotel in hotels_data:
    if hotel['name'] == row['name']:
      staff = [e["score"] for e in hotel['categoryReviews'] if e['title'] == "Staff"][0]
      facilities = [e["score"] for e in hotel['categoryReviews'] if e['title'] == "Facilities"][0]
      cleanliness = [e["score"] for e in hotel['categoryReviews'] if e['title'] == "Cleanliness"][0]
      comfort = [e["score"] for e in hotel['categoryReviews'] if e['title'] == "Comfort"][0]
      valueForMoney = [e["score"] for e in hotel['categoryReviews'] if e['title'] == "Value for money"][0]
      location = [e["score"] for e in hotel['categoryReviews'] if e['title'] == "Location"][0]
      fixed_row = [hotel['stars'], hotel['rating'], hotel['reviews'], staff, facilities, cleanliness, comfort, valueForMoney, location]

  denorm_df_rows.append(row.to_list() + fixed_row)

# %%
fixed_df = pd.DataFrame(denorm_df_rows, columns=['name', 'city', 'Width', 'Height', 'Brightness', 'Color', 'Dominate',
       'description', 'stars', 'price', 'rating', 'reviews', 'image', 'images',
       'categoryReviews', 'userReviews', 'staff', 'facilities', 'cleanliness',
       'comfort', 'valueForMoney', 'location', 'albuquerque', 'austin',
       'baltimore', 'bonston', 'calgary', 'charlotte', 'chicago', 'columbus',
       'dallas', 'denver', 'detroit', 'el_paso', 'fort_worth', 'fresno',
       'houston', 'indianapolis', 'jacksonville', 'kansas', 'las_vegas',
       'los_angeles', 'louiseville', 'memphis', 'mesa', 'milwaukee',
       'montreal', 'nashville', 'new_york', 'oklahoma_city', 'orlando',
       'philadelphia', 'phoenix', 'portland', 'sacramento', 'san_antonio',
       'san_diego', 'san_francisco', 'san_jose', 'seattle', 'toronto',
       'tucson', 'washington_dc', 'c1', 'c2', 'c3', 'd1', 'd2', 'd3',
       'travelweekly_year_built', 'travelweekly_num_floors',
       'travelweekly_num_rooms', 'travelweekly_chain',
       'travelweekly_events_num_rooms', 'travelweekly_events_total_sqft',
       'travelweekly_min_rate', 'travelweekly_max_rate', 'num_room_types',
       'standard_room_sqft', 'np_images_ten', 'f_stars', 'f_rating', 'f_reviews', 'f_staff', 'f_facilities', 'f_cleanliness', 'f_comfort', 'f_valueForMoney', 'f_location'])

# %%
# Get indexes of rows with bad data (star class should be between 1-5)
index_list = fixed_df[fixed_df.f_stars == 6].index.tolist()
print(index_list)
# Out:
# [262, 271, 290, 312]

# %%
imgs_df = imgs_df.drop(imgs_df.index[index_list]).reset_index(drop=True)
fixed_df = fixed_df.drop(fixed_df.index[index_list]).reset_index(drop=True)

# %%
tabular_df = fixed_df[['f_stars', 'f_rating', 'f_reviews',
       'f_staff', 'f_facilities', 'f_cleanliness',
       'f_comfort', 'f_valueForMoney', 'f_location',
       'travelweekly_year_built', 'travelweekly_num_floors',
       'travelweekly_num_rooms',
       'travelweekly_events_num_rooms', 'travelweekly_events_total_sqft',
       'travelweekly_min_rate', 'travelweekly_max_rate', 'num_room_types',
       'standard_room_sqft']]

# %%
print(len(tabular_df), len(imgs_df))
print(len(tabular_df.columns))
# Out:
# 466 466
# 18

# %%
nan_indexes = tabular_df[tabular_df.isna().any(axis=1)].index

imgs_df = imgs_df.drop(imgs_df.index[nan_indexes]).reset_index(drop=True)
tabular_df = tabular_df.drop(tabular_df.index[nan_indexes]).reset_index(drop=True)
print(len(tabular_df), len(imgs_df))
print(len(tabular_df.columns))
# Out:
# 298 298
# 18

# %%
imgs_df[['np_images_ten']].to_pickle('imgs_df.pickle.gzde', compression='gzip') # saved to 1sjcMEd6UfNyrFSdcyf7ZZEkyPZdbZBr2
tabular_df.to_pickle('tabular_df.pickle.gzde', compression='gzip') # saved to 1f-EiqI0UEcWD0OT_9UP74SDUzpn1J9XA

# %%
#
# Dataset is successfully built! You can now move on to building the model(s).
#

# %% [markdown]
# # **minprice Prediction Using Multimodal Dataset**
# Using the custom dataset, predict minprice using keras and tensorflow

# %%
# Import useful libraries for data processing
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from io import BytesIO
from PIL import Image
import seaborn as sns
import pandas as pd
import numpy as np
import pickle
import json
import ast
import cv2

# %% [markdown]
# 1. Install gdown lib
# 2. Download the model's custom img dataset to 'imgs_df.pickle.gzde'
# 3. Download the model's custom tabular dataset to 'tabular_df.pickle.gzde'

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1sjcMEd6UfNyrFSdcyf7ZZEkyPZdbZBr2 #imgs_df
# !gdown https://drive.google.com/uc?id=1f-EiqI0UEcWD0OT_9UP74SDUzpn1J9XA #tabular_df
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1sjcMEd6UfNyrFSdcyf7ZZEkyPZdbZBr2
# From (redirected): https://drive.google.com/uc?id=1sjcMEd6UfNyrFSdcyf7ZZEkyPZdbZBr2&confirm=t&uuid=7f58058e-37d7-4abc-bfe0-cea8f2b9d417
# To: /content/imgs_df.pickle.gzde
# 100% 3.15G/3.15G [00:48<00:00, 64.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1f-EiqI0UEcWD0OT_9UP74SDUzpn1J9XA
# To: /content/tabular_df.pickle.gzde
# 100% 9.28k/9.28k [00:00<00:00, 38.4MB/s]

# %% [markdown]
# First, load the downloaded imgs_df and tabular_df

# %%
# Load dfs
imgs_df = pd.read_pickle('imgs_df.pickle.gzde', compression='gzip')
tabular_df = pd.read_pickle('tabular_df.pickle.gzde', compression='gzip')

# %% [markdown]
# The imgs_df contains a row, np_images_ten with images in numpy array format
#
# Stitch images into images_output list or np arrays

# %%
images_output = []
for row_index, row in imgs_df.iterrows():
    stitched_image = np.zeros((256, 256, 3), dtype="uint8")
    individual_images = []

    for np_img in row['np_images_ten'][:4]:
      individual_images.append(np.array(cv2.resize(np_img, (128 , 128))))

    stitched_image[0:128, 0:128] = individual_images[0]
    stitched_image[0:128, 128:256] = individual_images[1]
    stitched_image[128:256, 0:128] = individual_images[2]
    stitched_image[128:256, 128:256] = individual_images[3]

    images_output.append(stitched_image)

# %%
# Visualize the stitched image for the first n=1 rows
for i in images_output[:1]:
    plt.imshow(i)

# %%
# Log individual image shape and collective image array dimensions
print('Stitched image shape:', images_output[1].shape)
img_arr = np.stack(images_output, dtype="object", axis=0)
print('Array of stitched images shape:', img_arr.shape)
# Out:
# Stitched image shape: (256, 256, 3)
# Array of stitched images shape: (298, 256, 256, 3)

# %% [markdown]
# # Import libraries for building and training the model

# %%
from sklearn import metrics, datasets, linear_model, preprocessing, utils
from keras.layers import Dense, Activation, Flatten, Dropout, Conv1D, Conv2D, MaxPooling2D, MaxPool2D, Embedding, Input, concatenate
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelBinarizer
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from matplotlib.pyplot import figure, show
from keras.models import Sequential, Model
from keras.preprocessing import sequence
from keras.utils import plot_model
from keras.optimizers import Adam
from keras import optimizers
import tensorflow as tf
import keras
import glob

# %%
# Split the data into training and dev+test sets, for both tabular data and image data
# dev+test sets will then be split into a dev set and a test set
x_tabular_train, x_tabular_devtest, x_images_train, x_images_devtest = train_test_split(tabular_df, img_arr, test_size=0.1, random_state=1)
x_tabular_dev, x_tabular_test, x_images_dev, x_images_test = train_test_split(x_tabular_devtest, x_images_devtest, test_size=0.1, random_state=1)

# Log dataset shapes
print('x_tabular_train shape =', x_tabular_train.shape)
print('x_tabular_dev shape =', x_tabular_dev.shape)
print('x_tabular_test shape =', x_tabular_test.shape)
print('---------------------------------------------')
print('x_images_train shape =', x_images_train.shape)
print('x_images_dev shape =', x_images_dev.shape)
print('x_images_test shape =', x_images_test.shape)
# Out:
# x_tabular_train shape = (268, 18)
# x_tabular_dev shape = (27, 18)
# x_tabular_test shape = (3, 18)
# ---------------------------------------------
# x_images_train shape = (268, 256, 256, 3)
# x_images_dev shape = (27, 256, 256, 3)
# x_images_test shape = (3, 256, 256, 3)

# %%
# Initialize y sets and convert all values to float32 format
print(pd.get_dummies(x_tabular_train['f_stars'], dtype=float))

y_train = pd.get_dummies(x_tabular_train['f_stars'], dtype=float)
if 1 not in y_train.columns:
    y_train['1'] = 0.0
y_train = y_train.values

y_dev = pd.get_dummies(x_tabular_dev['f_stars'], dtype=float)
if 1 not in y_dev.columns:
    y_dev['1'] = 0.0
y_dev = y_dev.values

y_test = pd.get_dummies(x_tabular_test['f_stars'], dtype=float)
if 1 not in y_test.columns:
    y_test['1'] = 0.0
y_test = y_test.values
# Out:
#        2    3    4    5
# 240  0.0  0.0  1.0  0.0
# 167  0.0  0.0  1.0  0.0
# 85   0.0  1.0  0.0  0.0
# 90   0.0  1.0  0.0  0.0
# 173  0.0  0.0  0.0  1.0
# ..   ...  ...  ...  ...
# 203  0.0  1.0  0.0  0.0
# 255  0.0  0.0  1.0  0.0
# 72   0.0  1.0  0.0  0.0
# 235  0.0  1.0  0.0  0.0
# 37   0.0  1.0  0.0  0.0
#
# [268 rows x 4 columns]

# %%
# Drop output columns from x sets and get values
x_tabular_train = x_tabular_train.drop(['f_stars', 'travelweekly_min_rate', 'travelweekly_max_rate'], axis=1).values
x_tabular_dev = x_tabular_dev.drop(['f_stars', 'travelweekly_min_rate', 'travelweekly_max_rate'], axis=1).values
x_tabular_test = x_tabular_test.drop(['f_stars', 'travelweekly_min_rate', 'travelweekly_max_rate'], axis=1).values

# %%
print('y_train shape =', y_train.shape)
print('y_dev shape =', y_dev.shape)
# Out:
# y_train shape = (268, 5)
# y_dev shape = (27, 5)

# %%
# Normalize tabular dataset using StandardScaler
scaler = StandardScaler()
x_tabular_train = scaler.fit_transform(np.asarray(x_tabular_train).astype(np.float32))
x_tabular_dev = scaler.fit_transform(np.asarray(x_tabular_dev).astype(np.float32))
x_tabular_test = scaler.fit_transform(np.asarray(x_tabular_test).astype(np.float32))

# Convert all image to float32 format
x_images_train = np.asarray(x_images_train).astype(np.float32)
x_images_dev = np.asarray(x_images_dev).astype(np.float32)
x_images_test = np.asarray(x_images_test).astype(np.float32)

# %%
# Build a tabular model with the following structure
tabular_inputs = Input(shape=(x_tabular_train.shape[1],))

tabular_x = keras.layers.Dense(16, activation="relu")(tabular_inputs)
tabular_x = keras.layers.Dense(32, activation="relu")(tabular_inputs)
tabular_y_stars_output = Dense(units=5, activation='softmax', name='tabular_y_stars_output')(tabular_x)


# Build a CNN model with the following structure
cnn_inputs = Input(shape=(256,256,3))

conv1 = Conv2D(256, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu')(cnn_inputs)
pool1 = MaxPooling2D(pool_size=(3, 2), strides=None)(conv1)
conv2 = Conv2D(128, kernel_size=(3, 3), strides=(1, 1),activation='relu')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
conv2 = Conv2D(64, kernel_size=(3, 3), strides=(1, 1),activation='relu')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
conv3 = Conv2D(64, kernel_size=(3, 3), strides=(1, 1),activation='relu')(pool2)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
conv4 = Conv2D(32, kernel_size=(3, 3), strides=(1, 1),activation='relu')(pool3)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
flatten1 = Flatten()(pool4)
dense1 = Dense(16, activation="relu")(flatten1)
cnn_y_stars_output = Dense(units=5, activation='softmax', name='cnn_y_stars_output')(dense1)

# %% [markdown]
# # Finally, build the main model...

# %%
# concatenate inputs from the tabular model and the cnn model
combined_Input = concatenate([tabular_y_stars_output, cnn_y_stars_output])
x = Dense(20, activation="relu")(combined_Input)
x = Dense(32, activation="relu")(x)
final_stars = Dense(units=5, activation='softmax', name='final_stars')(x)


# Setup model
checkpointer_cnn = ModelCheckpoint(filepath="./model_saved_1.keras", save_best_only=True)
adam = optimizers.Adam(learning_rate=0.001) # initialize adam optimizer
monitor = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, verbose=2, mode='auto') # params specific to star-model
model = Model(inputs=[tabular_inputs, cnn_inputs], outputs=final_stars)

# Define loss function and compile model
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=adam)

# Train the model on the training dataset
try:
  model.fit(
      [x_tabular_train, x_images_train], y_train, callbacks=[checkpointer_cnn, monitor],
      validation_data=([x_tabular_dev, x_images_dev], y_dev),
      epochs=100)
except InterruptedError:
  print('Execution stopped.')
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.3680 - loss: 1.5754 - val_accuracy: 0.5556 - val_loss: 1.4943
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.4766 - loss: 1.4948 - val_accuracy: 0.5556 - val_loss: 1.4239
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.4731 - loss: 1.4155 - val_accuracy: 0.5556 - val_loss: 1.3578
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.4939 - loss: 1.3362 - val_accuracy: 0.5556 - val_loss: 1.3012
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.4915 - loss: 1.2821 - val_accuracy: 0.5556 - val_loss: 1.2575
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.4620 - loss: 1.2505 - val_accuracy: 0.5556 - val_loss: 1.2243
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.4700 - loss: 1.1777 - val_accuracy: 0.5556 - val_loss: 1.1987
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.4658 - loss: 1.1981 - val_accuracy: 0.5556 - val_loss: 1.1832
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.4760 - loss: 1.1347 - val_accuracy: 0.5185 - val_loss: 1.1689
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6052 - loss: 1.0783 - val_accuracy: 0.4815 - val_loss: 1.1553
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.5711 - loss: 1.0628 - val_accuracy: 0.5556 - val_loss: 1.1516
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6865 - loss: 0.9561 - val_accuracy: 0.5556 - val_loss: 1.1383
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.6779 - loss: 1.0125 - val_accuracy: 0.5926 - val_loss: 1.1293
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6705 - loss: 1.0266 - val_accuracy: 0.6296 - val_loss: 1.1159
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6990 - loss: 0.9686 - val_accuracy: 0.6296 - val_loss: 1.1026
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7261 - loss: 0.9428 - val_accuracy: 0.6296 - val_loss: 1.0952
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.7168 - loss: 0.9389 - val_accuracy: 0.5926 - val_loss: 1.0860
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7232 - loss: 0.9130 - val_accuracy: 0.6296 - val_loss: 1.0710
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7057 - loss: 0.8951 - val_accuracy: 0.5926 - val_loss: 1.0554
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.6769 - loss: 0.9305 - val_accuracy: 0.6296 - val_loss: 1.0417
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7325 - loss: 0.8006 - val_accuracy: 0.6296 - val_loss: 1.0397
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7633 - loss: 0.7697 - val_accuracy: 0.6667 - val_loss: 1.0216
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7385 - loss: 0.8087 - val_accuracy: 0.6296 - val_loss: 1.0098
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7346 - loss: 0.8024 - val_accuracy: 0.6296 - val_loss: 0.9971
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.7256 - loss: 0.8307 - val_accuracy: 0.6296 - val_loss: 0.9838
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.7244 - loss: 0.8099 - val_accuracy: 0.6296 - val_loss: 0.9745
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.7501 - loss: 0.7818 - val_accuracy: 0.6296 - val_loss: 0.9601
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.7606 - loss: 0.7352 - val_accuracy: 0.6296 - val_loss: 0.9504
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.